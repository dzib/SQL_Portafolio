# %%
# %pip install pandas pygwalker sqlalchemy pyodbc python-dotenv
# Out:
# Collecting pandas
#   Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting pygwalker
#   Using cached pygwalker-0.5.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting sqlalchemy
#   Using cached sqlalchemy-2.0.49-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Collecting pyodbc
#   Using cached pyodbc-5.3.0-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting anywidget (from pygwalker)
#   Using cached anywidget-0.11.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting appdirs (from pygwalker)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting arrow (from pygwalker)
#   Using cached arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting astor (from pygwalker)
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting cachetools (from pygwalker)
#   Using cached cachetools-7.0.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting duckdb<2.0.0,>=0.10.4 (from pygwalker)
#   Using cached duckdb-1.5.2-cp314-cp314-win_amd64.whl.metadata (4.2 kB)
# Collecting gw-dsl-parser==0.1.49.1 (from pygwalker)
#   Using cached gw_dsl_parser-0.1.49.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting ipylab<=1.0.0 (from pygwalker)
#   Using cached ipylab-1.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: ipython in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from pygwalker) (9.13.0)
# Collecting ipywidgets (from pygwalker)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting jinja2 (from pygwalker)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting kanaries-track==0.0.5 (from pygwalker)
#   Using cached kanaries_track-0.0.5-py3-none-any.whl.metadata (913 bytes)
# Requirement already satisfied: packaging in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from pygwalker) (26.2)
# Requirement already satisfied: psutil in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from pygwalker) (7.2.2)
# Collecting pyarrow (from pygwalker)
#   Using cached pyarrow-24.0.0-cp314-cp314-win_amd64.whl.metadata (3.0 kB)
# Collecting pydantic (from pygwalker)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting pytz (from pygwalker)
#   Using cached pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from pygwalker)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting segment-analytics-python==2.2.3 (from pygwalker)
#   Using cached segment_analytics_python-2.2.3-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting sqlglot>=23.15.8 (from pygwalker)
#   Using cached sqlglot-30.6.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: traitlets in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from pygwalker) (5.14.3)
# Collecting typing-extensions (from pygwalker)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wasmtime>=12.0.0 (from gw-dsl-parser==0.1.49.1->pygwalker)
#   Using cached wasmtime-44.0.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# Collecting backoff>=2.2.1 (from kanaries-track==0.0.5->pygwalker)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting dateutils>=0.6.12 (from kanaries-track==0.0.5->pygwalker)
#   Using cached dateutils-0.6.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting monotonic~=1.5 (from segment-analytics-python==2.2.3->pygwalker)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipywidgets->pygwalker) (0.2.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->pygwalker)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->pygwalker)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six>=1.5 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests->pygwalker)
#   Using cached charset_normalizer-3.4.7-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests->pygwalker)
#   Using cached idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests->pygwalker)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests->pygwalker)
#   Using cached certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Using cached greenlet-3.5.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from ipython->pygwalker) (0.6.3)
# Requirement already satisfied: wcwidth in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->pygwalker) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from jedi>=0.18.2->ipython->pygwalker) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython->pygwalker) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython->pygwalker) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython->pygwalker) (0.2.3)
# Collecting psygnal>=0.8.1 (from anywidget->pygwalker)
#   Using cached psygnal-0.15.1-cp314-cp314-win_amd64.whl.metadata (6.1 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->pygwalker)
#   Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->pygwalker)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic->pygwalker)
#   Using cached pydantic_core-2.46.3-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic->pygwalker)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached pygwalker-0.5.0.1-py3-none-any.whl (4.8 MB)
# Using cached gw_dsl_parser-0.1.49.1-py3-none-any.whl (956 kB)
# Using cached kanaries_track-0.0.5-py3-none-any.whl (8.6 kB)
# Using cached segment_analytics_python-2.2.3-py2.py3-none-any.whl (24 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached duckdb-1.5.2-cp314-cp314-win_amd64.whl (13.6 MB)
# Using cached ipylab-1.0.0-py3-none-any.whl (100 kB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.7-cp314-cp314-win_amd64.whl (159 kB)
# Using cached idna-3.13-py3-none-any.whl (68 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Using cached sqlalchemy-2.0.49-cp314-cp314-win_amd64.whl (2.1 MB)
# Using cached pyodbc-5.3.0-cp314-cp314-win_amd64.whl (72 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Using cached greenlet-3.5.0-cp314-cp314-win_amd64.whl (239 kB)
# Using cached numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
# Using cached sqlglot-30.6.0-py3-none-any.whl (673 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached wasmtime-44.0.0-py3-none-win_amd64.whl (7.4 MB)
# Using cached anywidget-0.11.0-py3-none-any.whl (317 kB)
# Using cached psygnal-0.15.1-cp314-cp314-win_amd64.whl (423 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached arrow-1.4.0-py3-none-any.whl (68 kB)
# Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Using cached cachetools-7.0.6-py3-none-any.whl (13 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Using cached pyarrow-24.0.0-cp314-cp314-win_amd64.whl (28.0 MB)
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Using cached pydantic_core-2.46.3-cp314-cp314-win_amd64.whl (2.1 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: pytz, monotonic, appdirs, widgetsnbextension, wasmtime, urllib3, tzdata, typing-extensions, sqlglot, python-dotenv, pyodbc, pyarrow, psygnal, numpy, MarkupSafe, jupyterlab_widgets, idna, greenlet, duckdb, charset_normalizer, certifi, cachetools, backoff, astor, annotated-types, typing-inspection, sqlalchemy, requests, pydantic-core, pandas, jinja2, gw-dsl-parser, dateutils, arrow, segment-analytics-python, pydantic, kanaries-track, ipywidgets, ipylab, anywidget, pygwalker
#
#    ----------------------------------------  0/41 [pytz]
#    ----------------------------------------  0/41 [pytz]
#    ----------------------------------------  0/41 [pytz]
#    ----------------------------------------  0/41 [pytz]
#    ----------------------------------------  0/41 [pytz]
#    -- -------------------------------------  3/41 [widgetsnbextension]
#    --- ------------------------------------  4/41 [wasmtime]
#    --- ------------------------------------  4/41 [wasmtime]
#    --- ------------------------------------  4/41 [wasmtime]
#    --- ------------------------------------  4/41 [wasmtime]
#    --- ------------------------------------  4/41 [wasmtime]
#    ---- -----------------------------------  5/41 [urllib3]
#    ---- -----------------------------------  5/41 [urllib3]
#    ---- -----------------------------------  5/41 [urllib3]
#    ----- ----------------------------------  6/41 [tzdata]
#    ----- ----------------------------------  6/41 [tzdata]
#    ----- ----------------------------------  6/41 [tzdata]
#    ----- ----------------------------------  6/41 [tzdata]
#    ----- ----------------------------------  6/41 [tzdata]
#    ----- ----------------------------------  6/41 [tzdata]
#    ----- ----------------------------------  6/41 [tzdata]
#    ------ ---------------------------------  7/41 [typing-extensions]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    ------- --------------------------------  8/41 [sqlglot]
#    -------- -------------------------------  9/41 [python-dotenv]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ---------- ----------------------------- 11/41 [pyarrow]
#    ----------- ---------------------------- 12/41 [psygnal]
#    ----------- ---------------------------- 12/41 [psygnal]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    ------------ --------------------------- 13/41 [numpy]
#    --------------- ------------------------ 16/41 [idna]
#    --------------- ------------------------ 16/41 [idna]
#    ---------------- ----------------------- 17/41 [greenlet]
#    ----------------- ---------------------- 18/41 [duckdb]
#    ----------------- ---------------------- 18/41 [duckdb]
#    ----------------- ---------------------- 18/41 [duckdb]
#    ----------------- ---------------------- 18/41 [duckdb]
#    ------------------ --------------------- 19/41 [charset_normalizer]
#    --------------------- ------------------ 22/41 [backoff]
#    ----------------------- ---------------- 24/41 [annotated-types]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    ------------------------- -------------- 26/41 [sqlalchemy]
#    -------------------------- ------------- 27/41 [requests]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ---------------------------- ----------- 29/41 [pandas]
#    ----------------------------- ---------- 30/41 [jinja2]
#    ----------------------------- ---------- 30/41 [jinja2]
#    -------------------------------- ------- 33/41 [arrow]
#    ---------------------------------- ----- 35/41 [pydantic]
#    ---------------------------------- ----- 35/41 [pydantic]
#    ---------------------------------- ----- 35/41 [pydantic]
#    ---------------------------------- ----- 35/41 [pydantic]
#    ---------------------------------- ----- 35/41 [pydantic]
#    ----------------------------------- ---- 36/41 [kanaries-track]
#    ------------------------------------ --- 37/41 [ipywidgets]
#    ------------------------------------ --- 37/41 [ipywidgets]
#    ------------------------------------- -- 38/41 [ipylab]
#    ---------------------------------------  40/41 [pygwalker]
#    ---------------------------------------  40/41 [pygwalker]
#    ---------------------------------------  40/41 [pygwalker]
#    ---------------------------------------- 41/41 [pygwalker]
#
# Successfully installed MarkupSafe-3.0.3 annotated-types-0.7.0 anywidget-0.11.0 appdirs-1.4.4 arrow-1.4.0 astor-0.8.1 backoff-2.2.1 cachetools-7.0.6 certifi-2026.4.22 charset_normalizer-3.4.7 dateutils-0.6.12 duckdb-1.5.2 greenlet-3.5.0 gw-dsl-parser-0.1.49.1 idna-3.13 ipylab-1.0.0 ipywidgets-8.1.8 jinja2-3.1.6 jupyterlab_widgets-3.0.16 kanaries-track-0.0.5 monotonic-1.6 numpy-2.4.4 pandas-3.0.2 psygnal-0.15.1 pyarrow-24.0.0 pydantic-2.13.3 pydantic-core-2.46.3 pygwalker-0.5.0.1 pyodbc-5.3.0 python-dotenv-1.2.2 pytz-2026.1.post1 requests-2.33.1 segment-analytics-python-2.2.3 sqlalchemy-2.0.49 sqlglot-30.6.0 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2026.2 urllib3-2.6.3 wasmtime-44.0.0 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pygwalker as pyg
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
import urllib

# 1. Carga de entorno y conexión (Formato Dzib)
load_dotenv(override=True)
server = os.getenv('DB_SERVER')
database = os.getenv('DB_NAME')
driver = "ODBC Driver 17 for SQL Server"

params = urllib.parse.quote_plus(f"DRIVER={{{driver}}};SERVER={server};DATABASE={database};Trusted_Connection=yes;")
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

# 2. Consumo de Vistas Analíticas
print("📊 Extrayendo datos desde SQL Server...")
df_logistics = pd.read_sql("SELECT * FROM Analytics.vw_Shipping_Efficiency", engine)
df_performance = pd.read_sql("SELECT * FROM Analytics.vw_Category_Performance", engine)

# Validación de contenido (Métrica de éxito: filas recuperadas)
print(f"✅ Filas recuperadas (Logística): {len(df_logistics)}")
print(f"✅ Filas recuperadas (Desempeño): {len(df_performance)}")

# 3. Lanzamiento de Interfaz Interactiva
# Con esto se abrirá una interfaz tipo Tableau dentro del VS Code
if not df_logistics.empty:
    print("🚀 Lanzando interfaz interactiva...")
    walker = pyg.walk(df_logistics)
else:
    print("❌ ERROR: El DataFrame de logística está vacío. Revisa la vista en SQL.")
# Out:
# 📊 Extrayendo datos desde SQL Server...
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 24
#      20 df_performance = pd.read_sql("SELECT * FROM Analytics.vw_Category_Performance", engine)
#      21
#      22 # 3. Lanzamiento de Interfaz Interactiva
#      23 # Con esto se abrirá una interfaz tipo Tableau dentro del VS Code
# ---> 24 walker = pyg.walk(df_logistics, spec="./chart_meta.json")
#
# File c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages\pygwalker\api\adapter.py:51, in walk(dataset, gid, env, field_specs, theme_key, appearance, spec, use_kernel_calc, kernel_computation, cloud_computation, show_cloud_tool, kanaries_api_key, default_tab, **kwargs)
#      49 cur_env = get_current_env()
#      50 if cur_env == "jupyter":
# ---> 51     return jupyter.walk(
#      52         dataset,
#      53         gid,
#      54         env=env,
#      55         field_specs=field_specs,
#      56         theme_key=theme_key,
#      57         appearance=appearance,
#      58         spec=spec,
#      59         use_kernel_calc=use_kernel_calc,
#      60         kernel_computation=kernel_computation,
#      61         cloud_computation=cloud_computation,
#      62         show_cloud_tool=show_cloud_tool,
#      63         kanaries_api_key=kanaries_api_key,
#      64         default_tab=default_tab,
#      65         **kwargs
#      66     )
#      68 return webserver.walk(
#      69     dataset,
#      70     gid,
#    (...)     82     **kwargs
#      83 )
#
# File c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages\pygwalker\api\jupyter.py:69, in walk(dataset, gid, env, field_specs, theme_key, appearance, spec, use_kernel_calc, kernel_computation, cloud_computation, show_cloud_tool, kanaries_api_key, default_tab, **kwargs)
#      66 elif check_convert():
#      67     env = "JupyterConvert"
# ---> 69 walker = PygWalker(
#      70     gid=gid,
#      71     dataset=dataset,
#      72     field_specs=field_specs,
#      73     spec=spec,
#      74     source_invoke_code=source_invoke_code,
#      75     theme_key=theme_key,
#      76     appearance=appearance,
#      77     show_cloud_tool=show_cloud_tool,
#      78     use_preview=True,
#      79     kernel_computation=env != "JupyterConvert" and (isinstance(dataset, (Connector, str)) or fallback_value(kernel_computation, use_kernel_calc)),
#      80     use_save_tool=True,
#      81     gw_mode="explore",
#      82     is_export_dataframe=True,
#      83     kanaries_api_key=kanaries_api_key,
#      84     default_tab=default_tab,
#      85     cloud_computation=cloud_computation,
#      86     **kwargs
#      87 )
#      89 env_display_map = {
#      90     "JupyterWidget": walker.display_on_jupyter_use_widgets,
#      91     "Jupyter": walker.display_on_jupyter,
#      92     "JupyterConvert": walker.display_on_convert_html,
#      93     "JupyterPreview": walker.display_preview_on_jupyter
#      94 }
#      96 display_func = env_display_map.get(env, lambda: None)
#
# File c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages\pygwalker\api\pygwalker.py:86, in PygWalker.__init__(self, gid, dataset, field_specs, spec, source_invoke_code, theme_key, appearance, show_cloud_tool, use_preview, kernel_computation, cloud_computation, use_save_tool, is_export_dataframe, kanaries_api_key, default_tab, gw_mode, **kwargs)
#      77 self.cloud_service = CloudService(self.kanaries_api_key)
#      78 self.data_parser = self._get_data_parser(
#      79     dataset=dataset,
#      80     field_specs=field_specs,
#    (...)     83     cloud_service=self.cloud_service
#      84 )
# ---> 86 suggest_kernel_computation = self.data_parser.data_size > JUPYTER_BYTE_LIMIT
#      87 self.kernel_computation = suggest_kernel_computation if kernel_computation is None else kernel_computation
#      88 self.origin_data_source = self.data_parser.to_records(500 if self.kernel_computation else None)
#
# File c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages\pygwalker\data_parsers\base.py:228, in BaseDataFrameDataParser.data_size(self)
#     225 @property
#     226 def data_size(self) -> int:
#     227     datas = self.to_records(300)
# --> 228     avg_size = estimate_average_data_size(datas)
#     229     return avg_size * self.df.shape[0]
#
# File c:\Users\Dzib\source\repos\dzib\SQL_Portafolio\P4_Real_World_Ingestion\.venv\Lib\site-packages\pygwalker\utils\estimate_tools.py:11, in estimate_average_data_size(datas)
#       9 smp0 = datas[::max(len(datas)//32, 1)]
#      10 smp1 = datas[::max(len(datas)//37, 1)]
# ---> 11 avg_size = len(json.dumps(smp0, cls=DataFrameEncoder)) / len(smp0)
#      12 avg_size = max(avg_size, len(json.dumps(smp1, cls=DataFrameEncoder)) / len(smp1))
#      13 return avg_size
#
# ZeroDivisionError: division by zero
